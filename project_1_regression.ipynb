# %% [markdown]
# ##importing libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##Importing raw data

# %%
path_train = "/train (2).csv"

df_train = pd.read_csv(path_train)
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
path_test = "/test (3).csv"
df_test = pd.read_csv(path_test)
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
path_sample_submission = "/sample_submission (2).csv"

df_sample_submission = pd.read_csv(path_sample_submission)
df_sample_submission.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %% [markdown]
# ##Preprocessing

# %% [markdown]
# #Exploring the descriptive statistics of the variables

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
print(f' The dataframe df_train has {df_train.shape[0]} rows and {df_train.shape[1]} columns.')
print(f' The dataframe df_test has {df_test.shape[0]} rows and {df_test.shape[1]} columns.')
# Out:
#  The dataframe df_train has 1460 rows and 81 columns.
#  The dataframe df_test has 1459 rows and 80 columns.

# %%
print(df_train.columns.values)
# Out:
# ['Id' 'MSSubClass' 'MSZoning' 'LotFrontage' 'LotArea' 'Street' 'Alley'
#  'LotShape' 'LandContour' 'Utilities' 'LotConfig' 'LandSlope'
#  'Neighborhood' 'Condition1' 'Condition2' 'BldgType' 'HouseStyle'
#  'OverallQual' 'OverallCond' 'YearBuilt' 'YearRemodAdd' 'RoofStyle'
#  'RoofMatl' 'Exterior1st' 'Exterior2nd' 'MasVnrType' 'MasVnrArea'
#  'ExterQual' 'ExterCond' 'Foundation' 'BsmtQual' 'BsmtCond' 'BsmtExposure'
#  'BsmtFinType1' 'BsmtFinSF1' 'BsmtFinType2' 'BsmtFinSF2' 'BsmtUnfSF'
#  'TotalBsmtSF' 'Heating' 'HeatingQC' 'CentralAir' 'Electrical' '1stFlrSF'
#  '2ndFlrSF' 'LowQualFinSF' 'GrLivArea' 'BsmtFullBath' 'BsmtHalfBath'
#  'FullBath' 'HalfBath' 'BedroomAbvGr' 'KitchenAbvGr' 'KitchenQual'
#  'TotRmsAbvGrd' 'Functional' 'Fireplaces' 'FireplaceQu' 'GarageType'
#  'GarageYrBlt' 'GarageFinish' 'GarageCars' 'GarageArea' 'GarageQual'
#  'GarageCond' 'PavedDrive' 'WoodDeckSF' 'OpenPorchSF' 'EnclosedPorch'
#  '3SsnPorch' 'ScreenPorch' 'PoolArea' 'PoolQC' 'Fence' 'MiscFeature'
# ...

# %% [markdown]
# #Determining the variables of interest

# %% [markdown]
# #Dealing with missing values

# %%
nas = df_train.isna().sum()
nas[nas>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# replace the missing values with the mean

## for convenience, create a function to do that:
def fill_na_mean(df, column):
    df[column] = df[column].fillna(df[column].mean())

## define a list of columns to be imputed
columns_to_mean = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

## apply the function to the dataframe
for column in columns_to_mean:
    fill_na_mean(df_train, column)

## Note: this is the primitive syntax that was replaced by the function above and the for loop above:
# df_train['LotFrontage'] = df_train['LotFrontage'].fillna(df_train['LotFrontage'].mean())
# df_train['MasVnrArea'] = df_train['MasVnrArea'].fillna(df_train['MasVnrArea'].mean())
# df_train['GarageYrBlt'] = df_train['GarageYrBlt'].fillna(df_train['GarageYrBlt'].mean())

# %%
print(df_train.shape)
nas1 = df_train.isna().sum()
print(nas1[nas1>0])
# Out:
# (1460, 81)
# Alley           1369
# MasVnrType         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# replace the missing values with the most frequent value (see the replacement with the mean)

## for convenience, create a function to do that:
def fill_na_mode(df, column):
    df[column] = df[column].fillna(df[column].mode()[0])

## define a list of columns to be imputed
columns_to_mode = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
                   'Electrical', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']

## apply the function to the dataframe
for column in columns_to_mode:
    fill_na_mode(df_train, column)

# %%
print(df_train.shape)
nas2 = df_train.isna().sum()
print(nas2[nas2>0])
# Out:
# (1460, 81)
# Alley          1369
# MasVnrType        8
# FireplaceQu     690
# PoolQC         1453
# Fence          1179
# MiscFeature    1406
# dtype: int64

# %%
# dropping the columns with too much missing values

## defining a list of columns to be dropped
columns_to_drop = ['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

df_train.drop(columns_to_drop, axis=1, inplace=True)
        # alley - spis dalsi kategorie (pozn od Bohouse)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_train.shape
# Out:
# (1460, 75)

# %%
# controlling that I have no missing values
nas2 = df_train.isna().sum()
nas2[nas2>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# #Creating dummy variables

# %%
df_train_with_dummies = pd.get_dummies(df_train, drop_first=True) # drop_first=True to avoid dummy variable trap
#df_train_with_dummies = df_train_with_dummies.map(lambda x: int(x) if isinstance(x, bool) else x)
df_train_with_dummies = df_train_with_dummies.astype(int)

# %%
df_train_with_dummies.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60           65     8450            7            5       2003
# 1   2          20           80     9600            6            8       1976
# 2   3          60           68    11250            7            5       2001
# 3   4          70           60     9550            7            5       1915
# 4   5          60           84    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003         196         706  ...               0               0
# 1          1976           0         978  ...               0               0
# 2          2002         162         486  ...               0               0
# 3          1970           0         216  ...               0               0
# 4          2000         350         655  ...               0               0
#
# ...

# %%
df_train_with_dummies.shape
# Out:
# (1460, 231)

# %% [markdown]
# #Rearranging the columns

# %%
print(df_train_with_dummies.columns.values)
# Out:
# ['Id' 'MSSubClass' 'LotFrontage' 'LotArea' 'OverallQual' 'OverallCond'
#  'YearBuilt' 'YearRemodAdd' 'MasVnrArea' 'BsmtFinSF1' 'BsmtFinSF2'
#  'BsmtUnfSF' 'TotalBsmtSF' '1stFlrSF' '2ndFlrSF' 'LowQualFinSF'
#  'GrLivArea' 'BsmtFullBath' 'BsmtHalfBath' 'FullBath' 'HalfBath'
#  'BedroomAbvGr' 'KitchenAbvGr' 'TotRmsAbvGrd' 'Fireplaces' 'GarageYrBlt'
#  'GarageCars' 'GarageArea' 'WoodDeckSF' 'OpenPorchSF' 'EnclosedPorch'
#  '3SsnPorch' 'ScreenPorch' 'PoolArea' 'MiscVal' 'MoSold' 'YrSold'
#  'SalePrice' 'MSZoning_FV' 'MSZoning_RH' 'MSZoning_RL' 'MSZoning_RM'
#  'Street_Pave' 'LotShape_IR2' 'LotShape_IR3' 'LotShape_Reg'
#  'LandContour_HLS' 'LandContour_Low' 'LandContour_Lvl' 'Utilities_NoSeWa'
#  'LotConfig_CulDSac' 'LotConfig_FR2' 'LotConfig_FR3' 'LotConfig_Inside'
#  'LandSlope_Mod' 'LandSlope_Sev' 'Neighborhood_Blueste'
#  'Neighborhood_BrDale' 'Neighborhood_BrkSide' 'Neighborhood_ClearCr'
#  'Neighborhood_CollgCr' 'Neighborhood_Crawfor' 'Neighborhood_Edwards'
# ...

# %%
try:
    column_index = df_train_with_dummies.columns.get_loc('SalePrice')
    print("Index of the column 'SalePrice':", column_index)
except KeyError:
    print("Column not found.")
# Out:
# Index of the column 'SalePrice': 37

# %% [markdown]
# #Regression model

# %% [markdown]
# #Declaring the inputs and the targets

# %%
y = df_train_with_dummies['SalePrice']
X = df_train_with_dummies.drop(['SalePrice'],axis=1) # data_preprocessed.iloc[:,1:]

# %%
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
X.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60           65     8450            7            5       2003
# 1   2          20           80     9600            6            8       1976
# 2   3          60           68    11250            7            5       2001
# 3   4          70           60     9550            7            5       1915
# 4   5          60           84    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003         196         706  ...               0               0
# 1          1976           0         978  ...               0               0
# 2          2002         162         486  ...               0               0
# 3          1970           0         216  ...               0               0
# 4          2000         350         655  ...               0               0
#
# ...

# %% [markdown]
# #Linear regression model

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
r2_linreg_train = reg.score(X_train,y_train)
r2_linreg_train
# Out:
# 0.9327201504359315

# %%
r2_linreg_test = reg.score(X_test,y_test)
r2_linreg_test
# Out:
# 0.6350842652474722

# %% [markdown]
# #Polynomial features

# %% [markdown]
# #Polynomial features - universal

# %%
# with splitting the data into train and test
# with scaling the data

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn import config_context


for i in range(1, 3):
  poly = PolynomialFeatures(i, include_bias=True)
  with config_context(transform_output="pandas"):
      # the output of transform will be a Pandas DataFrame
      scaler = StandardScaler()
      X_train_poly = poly.fit_transform(X_train)
      X_train_scaled = scaler.fit_transform(X_train_poly)
      X_test_poly = poly.transform(X_test)
      X_test_scaled = scaler.transform(X_test_poly)

  reg_poly = LinearRegression()
  reg_poly.fit(X_train_scaled, y_train)


  print(f'All features with Polynomial features with degree {i}, with Y-intercept - train', reg_poly.score(X_train_scaled, y_train))
  print(f'All features with Polynomial features with degree {i}, with Y-intercept - test', reg_poly.score(X_test_scaled, y_test))
  print(X_train_scaled.shape)
# Out:
# All features with Polynomial features with degree 1, with Y-intercept - train 0.9327175075198563
# All features with Polynomial features with degree 1, with Y-intercept - test -9.133786970597419e+21
# (1168, 231)
# All features with Polynomial features with degree 2, with Y-intercept - train 1.0
# All features with Polynomial features with degree 2, with Y-intercept - test -0.0315255370867118
# (1168, 26796)

# %%
# without scaling the data
for i in range(1, 3):
  poly = PolynomialFeatures(i, include_bias=True)
  with config_context(transform_output="pandas"):
      # the output of transform will be a Pandas DataFrame
      X_train_poly = poly.fit_transform(X_train)
      X_test_poly = poly.transform(X_test)

  reg_poly = LinearRegression()
  reg_poly.fit(X_train_poly, y_train)

  print(f'All features with Polynomial features with degree {i}, with Y-intercept - train', reg_poly.score(X_train_poly, y_train))
  print(f'All features with Polynomial features with degree {i}, with Y-intercept - test', reg_poly.score(X_test_poly, y_test))
  print(X_train_poly.shape)
# Out:
# All features with Polynomial features with degree 1, with Y-intercept - train 0.9327201504359316
# All features with Polynomial features with degree 1, with Y-intercept - test 0.6350842652480322
# (1168, 231)
# All features with Polynomial features with degree 2, with Y-intercept - train 1.0
# All features with Polynomial features with degree 2, with Y-intercept - test -6.246997805723613
# (1168, 26796)

# %% [markdown]
# #Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# without scaling the data
for i in range(1, 3):
  poly = PolynomialFeatures(i, include_bias=True)
  with config_context(transform_output="pandas"):
      # the output of transform will be a Pandas DataFrame
      X_train_poly = poly.fit_transform(X_train)
      X_test_poly = poly.transform(X_test)

  reg_DecTreeReg = DecisionTreeRegressor()
  reg_DecTreeReg.fit(X_train_poly, y_train)

  print(f'All features with Polynomial features with degree {i}, with Y-intercept - train', reg_DecTreeReg.score(X_train_poly, y_train))
  print(f'All features with Polynomial features with degree {i}, with Y-intercept - test', reg_DecTreeReg.score(X_test_poly, y_test))
  print(X_train_poly.shape)
# Out:
# All features with Polynomial features with degree 1, with Y-intercept - train 1.0
# All features with Polynomial features with degree 1, with Y-intercept - test 0.7857594694100123
# (1168, 231)
# All features with Polynomial features with degree 2, with Y-intercept - train 1.0
# All features with Polynomial features with degree 2, with Y-intercept - test 0.6189675506602708
# (1168, 26796)

# %%
# with scaling the data

for i in range(1, 3):
  poly = PolynomialFeatures(i, include_bias=True)
  with config_context(transform_output="pandas"):
      # the output of transform will be a Pandas DataFrame
      scaler = StandardScaler()
      X_train_poly = poly.fit_transform(X_train)
      X_train_scaled = scaler.fit_transform(X_train_poly)
      X_test_poly = poly.transform(X_test)
      X_test_scaled = scaler.transform(X_test_poly)

  reg_DecTreeReg = DecisionTreeRegressor()
  reg_DecTreeReg.fit(X_train_scaled, y_train)


  print(f'All features with Polynomial features with degree {i}, with Y-intercept - train', reg_DecTreeReg.score(X_train_scaled, y_train))
  print(f'All features with Polynomial features with degree {i}, with Y-intercept - test', reg_DecTreeReg.score(X_test_scaled, y_test))
  print(X_train_scaled.shape)
# Out:
# All features with Polynomial features with degree 1, with Y-intercept - train 1.0
# All features with Polynomial features with degree 1, with Y-intercept - test 0.7857495078399729
# (1168, 231)
# All features with Polynomial features with degree 2, with Y-intercept - train 1.0
# All features with Polynomial features with degree 2, with Y-intercept - test 0.5977735679116144
# (1168, 26796)

# %% [markdown]
# #Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# without scaling the data
for i in range(1, 3):
  poly = PolynomialFeatures(i, include_bias=True)
  with config_context(transform_output="pandas"):
      # the output of transform will be a Pandas DataFrame
      X_train_poly = poly.fit_transform(X_train)
      X_test_poly = poly.transform(X_test)

reg_RanForReg = RandomForestRegressor()
reg_RanForReg.fit(X_train_poly, y_train)

print(f'All features with Polynomial features with degree {i}, with Y-intercept - train', reg_DecTreeReg.score(X_train_poly, y_train))
print(f'All features with Polynomial features with degree {i}, with Y-intercept - test', reg_DecTreeReg.score(X_test_poly, y_test))
print(X_train_scaled.shape)
# Out:
# All features with Polynomial features with degree 2, with Y-intercept - train -18.59685800499197
# All features with Polynomial features with degree 2, with Y-intercept - test -19.828396945327366
# (1168, 26796)
